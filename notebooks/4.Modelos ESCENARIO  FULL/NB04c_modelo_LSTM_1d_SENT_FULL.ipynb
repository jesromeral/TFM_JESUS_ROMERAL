# %% [markdown]
# ### Notebook *NB04c – Modelo LSTM CON  FULL sentimiento (horizonte 1 día)*
# **Autor:** Jesús Daniel Romeral Cortina
#
# **Objetivo:**
# Entrenar y evaluar modelo LSTM utilizando variables financieras del S&P 500 junto con un conjunto ampliado de variables de sentimiento extraídas de noticias financieras (medianas, desviación típica y ratios), con el fin de analizar si la incorporación de sentimiento mejora la capacidad predictiva en la predicción direccional a 1 día frente al baseline sin sentimiento y a los modelos con sentmiento simplificado.
#
# **Metodología (resumen):**
# - Se aumentan las features de sentimiento a partir del dataset `sp500_sent_FULL.csv`.
# - **Split temporal**: train anterior a **2022-01-01** y test posterior.
# - Preparación de datos para LSTM mediante creación de secuencias con **lookback** fijo.
# - Validación temporal interna: el último 20% del conjunto de entrenamiento se usa como validación.
# - Las neuronas selecionadas son a partir de la mejor metrica sacada del modelo lstm 1d sin sentimiento para una compaación justa, manteniendo el resto de parámetros iguales.
# - Métrica principal: **ROC_AUC** (además de Acc, B_Acc, Precision, Recall y F1).
# - Métricas guardadas en `resultados_ml_1d_SENT_FULL.csv`.

# %%
import numpy as np
import pandas as pd
import os
import random
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score, confusion_matrix, roc_auc_score, precision_score, recall_score)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
# Out:
# 2026-02-20 10:51:17.602880: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
FAMILIA = "DL"
MODELO_BASE = "LSTM" 
HORIZONTE = "1d" 
SENTIMIENTO = "FULL"

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
MODEL_PATH   = "../../datos/sp500_sent_FULL.csv"
OUT_DIR = "../../resultados"
OUT_PATH = "../../resultados/resultados_lstm_1d_SENT_FULL.csv"

# %%
df = pd.read_csv(MODEL_PATH, parse_dates=["Date"])
df = df.sort_values("Date").set_index("Date")
df.head()
# Out:
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
# 2013-01-07  1461.890015  1466.469971  1456.619995  1466.469971  3304970000
# 2013-01-08  1457.150024  1461.890015  1451.640015  1461.890015  3601600000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  ...  \
# Date                                                                      ...
# 2013-01-02  0.025403          0          -0.000957          0   0.016942  ...
# 2013-01-03 -0.002086          1           0.008737          1   0.025403  ...
# 2013-01-04  0.004865          0           0.003805          1  -0.002086  ...
# 2013-01-07 -0.003123          0           0.006013          1   0.004865  ...
# 2013-01-08 -0.003242          1           0.010424          1  -0.003123  ...
#
#             sentiment_mean  sentiment_median  sentiment_std  n_news  \
# Date
# 2013-01-02        0.470913          0.448076       0.545041     4.0
# 2013-01-03        0.000000          0.000000       0.000000     2.0
# 2013-01-04        0.000000          0.000000       0.000000     1.0
# 2013-01-07        0.000000          0.000000       0.000000     2.0
# 2013-01-08        0.244576          0.000000       0.423618     3.0
#
#             pos_ratio  neg_ratio  neu_ratio  has_news  sentiment_filled  \
# Date
# 2013-01-02   0.500000        0.0   0.500000         1          0.470913
# 2013-01-03   0.000000        0.0   1.000000         1          0.000000
# 2013-01-04   0.000000        0.0   1.000000         1          0.000000
# 2013-01-07   0.000000        0.0   1.000000         1          0.000000
# 2013-01-08   0.333333        0.0   0.666667         1          0.244576
#
#             n_news_filled
# Date
# 2013-01-02              4
# 2013-01-03              2
# 2013-01-04              1
# 2013-01-07              2
# 2013-01-08              3
#
# [5 rows x 28 columns]

# %%
print("Shape:", df.shape)
print("Rango fechas:", df.index.min(), "-", df.index.max())
df.head(3)
# Out:
# Shape: (2811, 28)
# Rango fechas: 2013-01-02 00:00:00 - 2024-03-04 00:00:00
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  ...  \
# Date                                                                      ...
# 2013-01-02  0.025403          0          -0.000957          0   0.016942  ...
# 2013-01-03 -0.002086          1           0.008737          1   0.025403  ...
# 2013-01-04  0.004865          0           0.003805          1  -0.002086  ...
#
#             sentiment_mean  sentiment_median  sentiment_std  n_news  \
# Date
# 2013-01-02        0.470913          0.448076       0.545041     4.0
# 2013-01-03        0.000000          0.000000       0.000000     2.0
# 2013-01-04        0.000000          0.000000       0.000000     1.0
#
#             pos_ratio  neg_ratio  neu_ratio  has_news  sentiment_filled  \
# Date
# 2013-01-02        0.5        0.0        0.5         1          0.470913
# 2013-01-03        0.0        0.0        1.0         1          0.000000
# 2013-01-04        0.0        0.0        1.0         1          0.000000
#
#             n_news_filled
# Date
# 2013-01-02              4
# 2013-01-03              2
# 2013-01-04              1
#
# [3 rows x 28 columns]

# %% [markdown]
# **Target (1 día)**
# - *Target_1d* es la etiqueta binaria a predecir.
# - Se elimina features *forward* para evitar fuga de información.

# %%
Y = df["Target_1d"]
X = df.drop(columns=[
    "Target_1d", 
    "Target_5d", 
    "Return_5d_forward",
    "Close",
    "High",
    "Low",
    "Open",
    "Volume",
    "sentiment_mean", 
    "n_news"
]) 
X.head(3)
# Out:
#               Return  ret_lag_1  ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  \
# Date
# 2013-01-02  0.025403   0.016942  -0.011050  -0.001218  -0.004787  -0.002440
# 2013-01-03 -0.002086   0.025403   0.016942  -0.011050  -0.001218  -0.004787
# 2013-01-04  0.004865  -0.002086   0.025403   0.016942  -0.011050  -0.001218
#
#             ret_ma_5  ret_std_5  ret_ma_10  ret_std_10  sentiment_median  \
# Date
# 2013-01-02  0.005058   0.015419   0.002286    0.012203          0.448076
# 2013-01-03  0.005598   0.015030   0.000928    0.011814          0.000000
# 2013-01-04  0.006815   0.014580   0.002174    0.011468          0.000000
#
#             sentiment_std  pos_ratio  neg_ratio  neu_ratio  has_news  \
# Date
# 2013-01-02       0.545041        0.5        0.0        0.5         1
# 2013-01-03       0.000000        0.0        0.0        1.0         1
# 2013-01-04       0.000000        0.0        0.0        1.0         1
#
#             sentiment_filled  n_news_filled
# Date
# 2013-01-02          0.470913              4
# 2013-01-03          0.000000              2
# 2013-01-04          0.000000              1

# %% [markdown]
# **Split temporal por fecha (train/test)**
# Con embargo por horizonte

# %%
H = 1
train_mask = df.index < "2022-01-01"

X_train_raw = X.loc[train_mask].iloc[:-H]
y_train     = Y.loc[train_mask].iloc[:-H]

X_test_raw  = X.loc[~train_mask]
y_test      = Y.loc[~train_mask]

assert X_train_raw.index.max() < X_test_raw.index.min()
assert (X_train_raw.index == y_train.index).all()


print("Train:", X_train_raw.shape, "Test:",X_test_raw.shape)

pos_train = y_train.sum()
pos_test = y_test.sum()
print("Porcentaje positivos en train:", round(pos_train/ len(y_train) * 100, 1),"%")
print("Porcentaje positivos en test:", round(pos_test / len(y_test) * 100, 1),"%")
# Out:
# Train: (2266, 18) Test: (544, 18)
# Porcentaje positivos en train: 55.3 %
# Porcentaje positivos en test: 49.4 %

# %% [markdown]
# **Split temporal por fechas (train/val)** EN RAW + gap=H (embargo entre train y val)

# %%
val_size_raw = int(len(X_train_raw) * 0.2)
val_start_raw = len(X_train_raw) - val_size_raw

train_end_raw = max(0, val_start_raw - H)

X_tr_raw = X_train_raw.iloc[:train_end_raw]
y_tr = y_train.iloc[:train_end_raw]

X_val_raw = X_train_raw.iloc[val_start_raw:]
y_val = y_train.iloc[val_start_raw:]

# %%
print("TRAIN:", X_tr_raw.index[0],"-",X_tr_raw.index[-1],"n=", len(X_tr_raw))
print("VAL  :", X_val_raw.index[0],"-",X_val_raw.index[-1],  "n=", len(X_val_raw))
print("TEST :", X_test_raw.index[0],"-",X_test_raw.index[-1],"n=", len(X_test_raw))
# Out:
# TRAIN: 2013-01-02 00:00:00 - 2020-03-13 00:00:00 n= 1812
# VAL  : 2020-03-17 00:00:00 - 2021-12-30 00:00:00 n= 453
# TEST : 2022-01-03 00:00:00 - 2024-03-04 00:00:00 n= 544

# %% [markdown]
# **Escalado** (Fit solo al train real)

# %%
scaler = StandardScaler()
X_tr_scaled = scaler.fit_transform(X_tr_raw)
X_val_scaled = scaler.transform(X_val_raw)
X_test_scaled = scaler.transform(X_test_raw)

# %% [markdown]
# **Preparación de secuencias (LSTM)**

# %%
def make_sequences(X: np.ndarray, y: np.ndarray, lookback: int):
    X_seq, y_seq = [], []
    for t in range(lookback - 1, len(X)):
        X_seq.append(X[t - lookback + 1:t + 1])
        y_seq.append(y[t])
    return np.asarray(X_seq, np.float32), np.asarray(y_seq, np.int32)

# %%
lookback = 10  
X_tr_seq, y_tr_seq = make_sequences(X_tr_scaled, y_tr.values, lookback)
X_val_seq, y_val_seq = make_sequences(X_val_scaled, y_val.values, lookback)
X_test_seq, y_test_seq = make_sequences(X_test_scaled, y_test.values, lookback)

# %%
print(f"Entrenamiento: {X_tr_seq.shape}")
print(f"Prueba (validación): {X_val_seq.shape}") 
print(f"Prueba (Test): {X_test_seq.shape}")

print("X_tr_seq:", X_tr_seq.shape, "y_train_seq:", y_tr_seq.shape)
print("X_val_seq :", X_val_seq.shape,  "y_val_seq :", y_val_seq.shape)
print("X_test_seq :", X_test_seq.shape,  "y_test_seq :", y_test_seq.shape)

test_dates_seq = X_test_raw.index[lookback-1:]
print("Fechas test (seq):", test_dates_seq.min(), "->", test_dates_seq.max())
# Out:
# Entrenamiento: (1803, 10, 18)
# Prueba (validación): (444, 10, 18)
# Prueba (Test): (535, 10, 18)
# X_tr_seq: (1803, 10, 18) y_train_seq: (1803,)
# X_val_seq : (444, 10, 18) y_val_seq : (444,)
# X_test_seq : (535, 10, 18) y_test_seq : (535,)
# Fechas test (seq): 2022-01-14 00:00:00 -> 2024-03-04 00:00:00

# %% [markdown]
# **Ajuste de hiperparámetros (grid reducido) y entreno**
# - Se compara un conjunto reducido de tamaños de red (nº de neuronas: 32 y 64) para controlar la complejidad del modelo.
# - Se mantiene el resto de parámetros fijos.

# %%
n_features = X_tr_seq.shape[-1]

resultados_totales = []
neuronas_list = [32, 64] 

for neuronas in neuronas_list:
    print (f"Entrenando modelo {MODELO_BASE} {HORIZONTE} {SENTIMIENTO} sentimiento con {neuronas} neuronas...")
    model = models.Sequential([
        layers.Input(shape=(lookback, n_features)),
        layers.LSTM(neuronas, return_sequences=False,kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(neuronas//2, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="roc_auc", curve="ROC")])
    
    callbacks = [
        EarlyStopping(monitor="val_roc_auc", mode="max",patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_roc_auc", mode="max", factor=0.5, patience=5, min_lr=1e-5, verbose=1,)
    ]
  
    
    history = model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    
    y_proba = model.predict(X_test_seq, verbose=0).ravel()
    y_pred  = (y_proba >= 0.5).astype(int)  
    

    metrics = {
        "Familia": FAMILIA,
        "Modelo": f"{MODELO_BASE}_{neuronas}",
        "Horizonte": HORIZONTE,
        "Sentimiento" : SENTIMIENTO,
        "Acc": accuracy_score(y_test_seq, y_pred),
        "B_Acc": balanced_accuracy_score(y_test_seq, y_pred),
        "Precision": precision_score(y_test_seq, y_pred, zero_division=0),
        "Recall": recall_score(y_test_seq, y_pred, zero_division=0),
        "F1": f1_score(y_test_seq, y_pred, zero_division=0),
        "ROC_AUC": roc_auc_score(y_test_seq, y_proba),
        "Conf_Matrix": confusion_matrix(y_test_seq, y_pred),
    }





    resultados_totales.append(metrics)
# Out:
# Entrenando modelo LSTM 1d FULL sentimiento con 32 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5341 - loss: 0.6972 - roc_auc: 0.5038 - val_accuracy: 0.5541 - val_loss: 0.6903 - val_roc_auc: 0.4986 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5591 - loss: 0.6926 - roc_auc: 0.5346 - val_accuracy: 0.5653 - val_loss: 0.6897 - val_roc_auc: 0.4949 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5408 - loss: 0.6940 - roc_auc: 0.5202 - val_accuracy: 0.5766 - val_loss: 0.6888 - val_roc_auc: 0.5048 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5641 - loss: 0.6897 - roc_auc: 0.5570 - val_accuracy: 0.5743 - val_loss: 0.6897 - val_roc_auc: 0.4935 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5602 - loss: 0.6857 - roc_auc: 0.5720 - val_accuracy: 0.5833 - val_loss: 0.6889 - val_roc_auc: 0.4986 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5668 - loss: 0.6853 - roc_auc: 0.5826 - val_accuracy: 0.5676 - val_loss: 0.6884 - val_roc_auc: 0.5091 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5774 - loss: 0.6785 - roc_auc: 0.6053 - val_accuracy: 0.5788 - val_loss: 0.6889 - val_roc_auc: 0.5069 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5646 - loss: 0.6796 - roc_auc: 0.5929 - val_accuracy: 0.5698 - val_loss: 0.6895 - val_roc_auc: 0.5103 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5535 - loss: 0.6807 - roc_auc: 0.5906 - val_accuracy: 0.5653 - val_loss: 0.6901 - val_roc_auc: 0.5103 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5679 - loss: 0.6784 - roc_auc: 0.5960 - val_accuracy: 0.5766 - val_loss: 0.6882 - val_roc_auc: 0.5239 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5929 - loss: 0.6701 - roc_auc: 0.6291 - val_accuracy: 0.5563 - val_loss: 0.6898 - val_roc_auc: 0.5269 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5868 - loss: 0.6713 - roc_auc: 0.6221 - val_accuracy: 0.5518 - val_loss: 0.6890 - val_roc_auc: 0.5346 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5896 - loss: 0.6738 - roc_auc: 0.6145 - val_accuracy: 0.5586 - val_loss: 0.6884 - val_roc_auc: 0.5329 - learning_rate: 0.0010
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6034 - loss: 0.6674 - roc_auc: 0.6334 - val_accuracy: 0.5563 - val_loss: 0.6920 - val_roc_auc: 0.5291 - learning_rate: 0.0010
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5973 - loss: 0.6638 - roc_auc: 0.6431 - val_accuracy: 0.5518 - val_loss: 0.6901 - val_roc_auc: 0.5363 - learning_rate: 0.0010
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6251 - loss: 0.6592 - roc_auc: 0.6560 - val_accuracy: 0.5563 - val_loss: 0.6935 - val_roc_auc: 0.5349 - learning_rate: 0.0010
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6101 - loss: 0.6576 - roc_auc: 0.6572 - val_accuracy: 0.5721 - val_loss: 0.6929 - val_roc_auc: 0.5399 - learning_rate: 0.0010
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6206 - loss: 0.6540 - roc_auc: 0.6619 - val_accuracy: 0.5541 - val_loss: 0.6948 - val_roc_auc: 0.5477 - learning_rate: 0.0010
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6306 - loss: 0.6474 - roc_auc: 0.6756 - val_accuracy: 0.5608 - val_loss: 0.6957 - val_roc_auc: 0.5452 - learning_rate: 0.0010
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6445 - loss: 0.6366 - roc_auc: 0.6943 - val_accuracy: 0.5473 - val_loss: 0.7027 - val_roc_auc: 0.5492 - learning_rate: 0.0010
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6434 - loss: 0.6345 - roc_auc: 0.6973 - val_accuracy: 0.5428 - val_loss: 0.7025 - val_roc_auc: 0.5522 - learning_rate: 0.0010
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6517 - loss: 0.6269 - roc_auc: 0.7091 - val_accuracy: 0.5631 - val_loss: 0.7051 - val_roc_auc: 0.5551 - learning_rate: 0.0010
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6595 - loss: 0.6283 - roc_auc: 0.7064 - val_accuracy: 0.5360 - val_loss: 0.7095 - val_roc_auc: 0.5513 - learning_rate: 0.0010
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6611 - loss: 0.6188 - roc_auc: 0.7173 - val_accuracy: 0.5270 - val_loss: 0.7180 - val_roc_auc: 0.5489 - learning_rate: 0.0010
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6717 - loss: 0.6155 - roc_auc: 0.7257 - val_accuracy: 0.5203 - val_loss: 0.7281 - val_roc_auc: 0.5483 - learning_rate: 0.0010
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6656 - loss: 0.6134 - roc_auc: 0.7259 - val_accuracy: 0.5293 - val_loss: 0.7322 - val_roc_auc: 0.5537 - learning_rate: 0.0010
# Epoch 27/100
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6862 - loss: 0.5942 - roc_auc: 0.7535
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6644 - loss: 0.6061 - roc_auc: 0.7342 - val_accuracy: 0.5158 - val_loss: 0.7417 - val_roc_auc: 0.5446 - learning_rate: 0.0010
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6789 - loss: 0.5898 - roc_auc: 0.7568 - val_accuracy: 0.5270 - val_loss: 0.7488 - val_roc_auc: 0.5460 - learning_rate: 5.0000e-04
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6938 - loss: 0.5782 - roc_auc: 0.7702 - val_accuracy: 0.5248 - val_loss: 0.7527 - val_roc_auc: 0.5508 - learning_rate: 5.0000e-04
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6983 - loss: 0.5771 - roc_auc: 0.7694 - val_accuracy: 0.5203 - val_loss: 0.7653 - val_roc_auc: 0.5407 - learning_rate: 5.0000e-04
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6905 - loss: 0.5781 - roc_auc: 0.7694 - val_accuracy: 0.5158 - val_loss: 0.7710 - val_roc_auc: 0.5425 - learning_rate: 5.0000e-04
# Epoch 32/100
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7177 - loss: 0.5612 - roc_auc: 0.7948
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7060 - loss: 0.5761 - roc_auc: 0.7707 - val_accuracy: 0.5068 - val_loss: 0.7846 - val_roc_auc: 0.5406 - learning_rate: 5.0000e-04
# Entrenando modelo LSTM 1d FULL sentimiento con 64 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.5413 - loss: 0.6985 - roc_auc: 0.5094 - val_accuracy: 0.5721 - val_loss: 0.6933 - val_roc_auc: 0.4740 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5485 - loss: 0.6936 - roc_auc: 0.5413 - val_accuracy: 0.5833 - val_loss: 0.6910 - val_roc_auc: 0.5035 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5557 - loss: 0.6905 - roc_auc: 0.5617 - val_accuracy: 0.5788 - val_loss: 0.6908 - val_roc_auc: 0.5041 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5585 - loss: 0.6856 - roc_auc: 0.5750 - val_accuracy: 0.5676 - val_loss: 0.6920 - val_roc_auc: 0.5067 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5580 - loss: 0.6867 - roc_auc: 0.5741 - val_accuracy: 0.5586 - val_loss: 0.6916 - val_roc_auc: 0.5066 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5685 - loss: 0.6826 - roc_auc: 0.5926 - val_accuracy: 0.5518 - val_loss: 0.6918 - val_roc_auc: 0.5115 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5846 - loss: 0.6798 - roc_auc: 0.6064 - val_accuracy: 0.5405 - val_loss: 0.6914 - val_roc_auc: 0.5202 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5968 - loss: 0.6782 - roc_auc: 0.6090 - val_accuracy: 0.5428 - val_loss: 0.6910 - val_roc_auc: 0.5292 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5984 - loss: 0.6710 - roc_auc: 0.6282 - val_accuracy: 0.5495 - val_loss: 0.6899 - val_roc_auc: 0.5340 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6001 - loss: 0.6693 - roc_auc: 0.6285 - val_accuracy: 0.5518 - val_loss: 0.6925 - val_roc_auc: 0.5324 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6190 - loss: 0.6615 - roc_auc: 0.6528 - val_accuracy: 0.5631 - val_loss: 0.6933 - val_roc_auc: 0.5402 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6206 - loss: 0.6601 - roc_auc: 0.6532 - val_accuracy: 0.5631 - val_loss: 0.6967 - val_roc_auc: 0.5497 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6423 - loss: 0.6540 - roc_auc: 0.6655 - val_accuracy: 0.5563 - val_loss: 0.6986 - val_roc_auc: 0.5445 - learning_rate: 0.0010
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6384 - loss: 0.6428 - roc_auc: 0.6840 - val_accuracy: 0.5338 - val_loss: 0.7065 - val_roc_auc: 0.5424 - learning_rate: 0.0010
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6522 - loss: 0.6373 - roc_auc: 0.6931 - val_accuracy: 0.5473 - val_loss: 0.7118 - val_roc_auc: 0.5463 - learning_rate: 0.0010
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6628 - loss: 0.6274 - roc_auc: 0.7104 - val_accuracy: 0.5315 - val_loss: 0.7175 - val_roc_auc: 0.5496 - learning_rate: 0.0010
# Epoch 17/100
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6603 - loss: 0.6112 - roc_auc: 0.7332
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6578 - loss: 0.6207 - roc_auc: 0.7160 - val_accuracy: 0.5383 - val_loss: 0.7276 - val_roc_auc: 0.5417 - learning_rate: 0.0010
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6750 - loss: 0.6116 - roc_auc: 0.7295 - val_accuracy: 0.5518 - val_loss: 0.7307 - val_roc_auc: 0.5434 - learning_rate: 5.0000e-04
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6938 - loss: 0.5926 - roc_auc: 0.7586 - val_accuracy: 0.5360 - val_loss: 0.7450 - val_roc_auc: 0.5453 - learning_rate: 5.0000e-04
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6828 - loss: 0.5974 - roc_auc: 0.7492 - val_accuracy: 0.5450 - val_loss: 0.7496 - val_roc_auc: 0.5466 - learning_rate: 5.0000e-04
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7027 - loss: 0.5790 - roc_auc: 0.7727 - val_accuracy: 0.5428 - val_loss: 0.7651 - val_roc_auc: 0.5449 - learning_rate: 5.0000e-04
# Epoch 22/100
# 53/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7193 - loss: 0.5499 - roc_auc: 0.8090
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7022 - loss: 0.5692 - roc_auc: 0.7837 - val_accuracy: 0.5450 - val_loss: 0.7777 - val_roc_auc: 0.5445 - learning_rate: 5.0000e-04

# %% [markdown]
# **Guardado de resultados**
# - Exportación a CSV para combinar en Notebook de resultados `NB05a_Resultados.ipynb`

# %%
os.makedirs(OUT_DIR, exist_ok=True)

df_res = pd.DataFrame(resultados_totales)
df_res["Conf_Matrix"] = df_res["Conf_Matrix"].astype(str)
df_res.to_csv(OUT_PATH, index=False)
if os.path.exists(OUT_PATH): 
    print(f"Archivo guardado correctamente en {OUT_PATH}") 
else: 
    print("Error: el archivo no se ha guardado.")
df_res
# Out:
# Archivo guardado correctamente en ../../resultados/resultados_lstm_1d_SENT_FULL.csv
#   Familia   Modelo Horizonte Sentimiento       Acc     B_Acc  Precision  \
# 0      DL  LSTM_32        1d        FULL  0.530841  0.532535   0.517483
# 1      DL  LSTM_64        1d        FULL  0.540187  0.541954   0.522936
#
#      Recall        F1   ROC_AUC              Conf_Matrix
# 0  0.834586  0.638849  0.547614  [[ 62 207]\n [ 44 222]]
# 1  0.857143  0.649573  0.550368  [[ 61 208]\n [ 38 228]]
