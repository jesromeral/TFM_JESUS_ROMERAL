# %% [markdown]
# ### Notebook *NB02d – Modelo LSTM sin sentimiento (horizonte 5 días)*
# **Autor:** Jesús Daniel Romeral Cortina
#
# **Objetivo:**
# Entrenar y evaluar un modelo basado en redes neuronales recurrentes (LSTM) utilizando exclusivamente variables financieras del S&P 500, sin incorporar información de sentimiento, con el fin de establecer un baseline de referencia para la predicción direccional a 5 días.
#
# **Metodología (resumen):**
# - Se emplean únicamente variables financieras a partir del dataset `sp500_model.csv`.
# - **Split temporal**: train anterior a **2022-01-01** y test posterior.
# - Preparación de datos para LSTM mediante creación de secuencias con **lookback** fijo.
# - Validación temporal interna: el último 20% del conjunto de entrenamiento se usa como validación.
# - Ajuste de hiperparámetros limitado: se comparan dos tamaños de red (nº de neuronas, p. ej. 32 y 64), manteniendo el resto de parámetros fijos.
# - Métrica principal: **ROC_AUC** (además de Acc, B_Acc, Precision, Recall y F1).
# - Métricas guardadas en `resultados_lstm_5d.csv`.

# %%
import numpy as np
import pandas as pd
import os
import random
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score, confusion_matrix, roc_auc_score, precision_score, recall_score)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
# Out:
# 2026-03-02 22:24:39.243194: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
FAMILIA = "DL"
MODELO_BASE = "LSTM" 
HORIZONTE = "5d" 
SENTIMIENTO = "BASE"

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
MODEL_PATH   = "../../datos/sp500_model.csv"
OUT_DIR = "../../resultados"
OUT_PATH = "../../resultados/resultados_lstm_5d.csv"

# %%
df = pd.read_csv(MODEL_PATH, parse_dates=["Date"])
df = df.sort_values("Date").set_index("Date")
df.head()
# Out:
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
# 2013-01-07  1461.890015  1466.469971  1456.619995  1466.469971  3304970000
# 2013-01-08  1457.150024  1461.890015  1451.640015  1461.890015  3601600000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  \
# Date
# 2013-01-02  0.025403          0          -0.000957          0   0.016942
# 2013-01-03 -0.002086          1           0.008737          1   0.025403
# 2013-01-04  0.004865          0           0.003805          1  -0.002086
# 2013-01-07 -0.003123          0           0.006013          1   0.004865
# 2013-01-08 -0.003242          1           0.010424          1  -0.003123
#
#             ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  ret_ma_5  ret_std_5  \
# Date
# 2013-01-02  -0.011050  -0.001218  -0.004787  -0.002440  0.005058   0.015419
# 2013-01-03   0.016942  -0.011050  -0.001218  -0.004787  0.005598   0.015030
# 2013-01-04   0.025403   0.016942  -0.011050  -0.001218  0.006815   0.014580
# 2013-01-07  -0.002086   0.025403   0.016942  -0.011050  0.008400   0.012423
# 2013-01-08   0.004865  -0.002086   0.025403   0.016942  0.004363   0.012231
#
#             ret_ma_10  ret_std_10
# Date
# 2013-01-02   0.002286    0.012203
# 2013-01-03   0.000928    0.011814
# 2013-01-04   0.002174    0.011468
# 2013-01-07   0.001313    0.011515
# 2013-01-08   0.001926    0.011035

# %%
print("Shape:", df.shape)
print("Rango fechas:", df.index.min(), "-", df.index.max())
df.head(3)
# Out:
# Shape: (2811, 18)
# Rango fechas: 2013-01-02 00:00:00 - 2024-03-04 00:00:00
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  \
# Date
# 2013-01-02  0.025403          0          -0.000957          0   0.016942
# 2013-01-03 -0.002086          1           0.008737          1   0.025403
# 2013-01-04  0.004865          0           0.003805          1  -0.002086
#
#             ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  ret_ma_5  ret_std_5  \
# Date
# 2013-01-02  -0.011050  -0.001218  -0.004787  -0.002440  0.005058   0.015419
# 2013-01-03   0.016942  -0.011050  -0.001218  -0.004787  0.005598   0.015030
# 2013-01-04   0.025403   0.016942  -0.011050  -0.001218  0.006815   0.014580
#
#             ret_ma_10  ret_std_10
# Date
# 2013-01-02   0.002286    0.012203
# 2013-01-03   0.000928    0.011814
# 2013-01-04   0.002174    0.011468

# %% [markdown]
# **Target (5 dias)**
# - *Target_5d* es la etiqueta binaria a predecir.
# - Se elimina features *forward* para evitar fuga de información.

# %%
Y = df["Target_5d"]
X = df.drop(columns=[
    "Target_1d", 
    "Target_5d", 
    "Return_5d_forward",
    "Close",
    "High",
    "Low",
    "Open",
    "Volume"
]) 
X.head(3)
# Out:
#               Return  ret_lag_1  ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  \
# Date
# 2013-01-02  0.025403   0.016942  -0.011050  -0.001218  -0.004787  -0.002440
# 2013-01-03 -0.002086   0.025403   0.016942  -0.011050  -0.001218  -0.004787
# 2013-01-04  0.004865  -0.002086   0.025403   0.016942  -0.011050  -0.001218
#
#             ret_ma_5  ret_std_5  ret_ma_10  ret_std_10
# Date
# 2013-01-02  0.005058   0.015419   0.002286    0.012203
# 2013-01-03  0.005598   0.015030   0.000928    0.011814
# 2013-01-04  0.006815   0.014580   0.002174    0.011468

# %% [markdown]
# **Split temporal por fecha (train/test)**
# Con embargo por horizonte

# %%
H = 5
train_mask = df.index < "2022-01-01"

X_train_raw = X.loc[train_mask].iloc[:-H]
y_train     = Y.loc[train_mask].iloc[:-H]

X_test_raw  = X.loc[~train_mask]
y_test      = Y.loc[~train_mask]


assert X_train_raw.index.max() < X_test_raw.index.min()
assert (X_train_raw.index == y_train.index).all()


print("Train:", X_train_raw.shape, "Test:",X_test_raw.shape)

pos_train = y_train.sum()
pos_test = y_test.sum()
print("Porcentaje positivos en train:", round(pos_train/ len(y_train) * 100, 1),"%")
print("Porcentaje positivos en test:", round(pos_test / len(y_test) * 100, 1),"%")
# Out:
# Train: (2262, 10) Test: (544, 10)
# Porcentaje positivos en train: 62.2 %
# Porcentaje positivos en test: 55.7 %

# %% [markdown]
# **Split temporal por fechas (train/val)** EN RAW + gap=H (embargo entre train y val)

# %%
val_size_raw = int(len(X_train_raw) * 0.2)
val_start_raw = len(X_train_raw) - val_size_raw

train_end_raw = max(0, val_start_raw - H)  

X_tr_raw = X_train_raw.iloc[:train_end_raw]
y_tr = y_train.iloc[:train_end_raw]

X_val_raw = X_train_raw.iloc[val_start_raw:]
y_val = y_train.iloc[val_start_raw:]

# %%
print("TRAIN:", X_tr_raw.index[0],"-",X_tr_raw.index[-1],"n=", len(X_tr_raw))
print("VAL  :", X_val_raw.index[0],"-",X_val_raw.index[-1],  "n=", len(X_val_raw))
print("TEST :", X_test_raw.index[0],"-",X_test_raw.index[-1],"n=", len(X_test_raw))
# Out:
# TRAIN: 2013-01-02 00:00:00 - 2020-03-04 00:00:00 n= 1805
# VAL  : 2020-03-12 00:00:00 - 2021-12-23 00:00:00 n= 452
# TEST : 2022-01-03 00:00:00 - 2024-03-04 00:00:00 n= 544

# %% [markdown]
# **Escalado** (Fit solo al train real)

# %%
scaler = StandardScaler()
X_tr_scaled = scaler.fit_transform(X_tr_raw)
X_val_scaled = scaler.transform(X_val_raw)
X_test_scaled = scaler.transform(X_test_raw)

# %% [markdown]
# **Preparación de secuencias (LSTM)**

# %%
def make_sequences(X: np.ndarray, y: np.ndarray, lookback: int):
    X_seq, y_seq = [], []
    for t in range(lookback - 1, len(X)):
        X_seq.append(X[t - lookback + 1:t + 1])
        y_seq.append(y[t])
    return np.asarray(X_seq, np.float32), np.asarray(y_seq, np.int32)

# %%
lookback = 10  
X_tr_seq, y_tr_seq = make_sequences(X_tr_scaled, y_tr.values, lookback)
X_val_seq, y_val_seq = make_sequences(X_val_scaled, y_val.values, lookback)
X_test_seq, y_test_seq = make_sequences(X_test_scaled, y_test.values, lookback)

# %%
print(f"Entrenamiento: {X_tr_seq.shape}")
print(f"Prueba (validación): {X_val_seq.shape}") 
print(f"Prueba (Test): {X_test_seq.shape}")

print("X_tr_seq:", X_tr_seq.shape, "y_train_seq:", y_tr_seq.shape)
print("X_val_seq :", X_val_seq.shape,  "y_val_seq :", y_val_seq.shape)
print("X_test_seq :", X_test_seq.shape,  "y_test_seq :", y_test_seq.shape)

test_dates_seq = X_test_raw.index[lookback-1:]
print("Fechas test (seq):", test_dates_seq.min(), "->", test_dates_seq.max())
# Out:
# Entrenamiento: (1796, 10, 10)
# Prueba (validación): (443, 10, 10)
# Prueba (Test): (535, 10, 10)
# X_tr_seq: (1796, 10, 10) y_train_seq: (1796,)
# X_val_seq : (443, 10, 10) y_val_seq : (443,)
# X_test_seq : (535, 10, 10) y_test_seq : (535,)
# Fechas test (seq): 2022-01-14 00:00:00 -> 2024-03-04 00:00:00

# %% [markdown]
# **Ajuste de hiperparámetros (grid reducido)**
# - Se compara un conjunto reducido de tamaños de red (nº de neuronas: 32 y 64) para controlar la complejidad del modelo.
# - Se mantiene el resto de parámetros fijos.

# %%
n_features = X_tr_seq.shape[-1]

resultados_totales = []
neuronas_list = [32, 64] 

for neuronas in neuronas_list:
    print (f"Entrenando modelo {MODELO_BASE} {HORIZONTE} {SENTIMIENTO} sentimiento con {neuronas} neuronas...")
    model = models.Sequential([
        layers.Input(shape=(lookback, n_features)),
        layers.LSTM(neuronas, return_sequences=False,kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(neuronas//2, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="roc_auc", curve="ROC")])
    
    callbacks = [
        EarlyStopping(monitor="val_roc_auc", mode="max",patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_roc_auc", mode="max", factor=0.5, patience=5, min_lr=1e-5, verbose=1,)
    ]
  
    
    history = model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    
    y_proba = model.predict(X_test_seq, verbose=0).ravel()
    y_pred  = (y_proba >= 0.5).astype(int)  
    

    metrics = {
        "Familia": FAMILIA,
        "Modelo": f"{MODELO_BASE}_{neuronas}",
        "Horizonte": HORIZONTE,
        "Sentimiento" : SENTIMIENTO,
        "Acc": accuracy_score(y_test_seq, y_pred),
        "B_Acc": balanced_accuracy_score(y_test_seq, y_pred),
        "Precision": precision_score(y_test_seq, y_pred, zero_division=0),
        "Recall": recall_score(y_test_seq, y_pred, zero_division=0),
        "F1": f1_score(y_test_seq, y_pred, zero_division=0),
        "ROC_AUC": roc_auc_score(y_test_seq, y_proba),
        "Conf_Matrix": confusion_matrix(y_test_seq, y_pred),
    }





    resultados_totales.append(metrics)
# Out:
# Entrenando modelo LSTM 5d BASE sentimiento con 32 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6052 - loss: 0.6739 - roc_auc: 0.5311 - val_accuracy: 0.6524 - val_loss: 0.6624 - val_roc_auc: 0.4757 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6164 - loss: 0.6658 - roc_auc: 0.5501 - val_accuracy: 0.6524 - val_loss: 0.6578 - val_roc_auc: 0.5133 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6136 - loss: 0.6661 - roc_auc: 0.5609 - val_accuracy: 0.6524 - val_loss: 0.6601 - val_roc_auc: 0.5165 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6125 - loss: 0.6624 - roc_auc: 0.5740 - val_accuracy: 0.6524 - val_loss: 0.6602 - val_roc_auc: 0.5238 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6197 - loss: 0.6546 - roc_auc: 0.6115 - val_accuracy: 0.6524 - val_loss: 0.6690 - val_roc_auc: 0.5164 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6164 - loss: 0.6531 - roc_auc: 0.6112 - val_accuracy: 0.6524 - val_loss: 0.6777 - val_roc_auc: 0.5148 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6247 - loss: 0.6497 - roc_auc: 0.6205 - val_accuracy: 0.6479 - val_loss: 0.6833 - val_roc_auc: 0.5145 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6203 - loss: 0.6446 - roc_auc: 0.6375 - val_accuracy: 0.6388 - val_loss: 0.6967 - val_roc_auc: 0.5028 - learning_rate: 0.0010
# Epoch 9/100
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6407 - loss: 0.6356 - roc_auc: 0.6496
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6253 - loss: 0.6434 - roc_auc: 0.6352 - val_accuracy: 0.6321 - val_loss: 0.7109 - val_roc_auc: 0.4958 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6364 - loss: 0.6406 - roc_auc: 0.6439 - val_accuracy: 0.6343 - val_loss: 0.7155 - val_roc_auc: 0.5053 - learning_rate: 5.0000e-04
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6320 - loss: 0.6357 - roc_auc: 0.6542 - val_accuracy: 0.6343 - val_loss: 0.7350 - val_roc_auc: 0.4933 - learning_rate: 5.0000e-04
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6498 - loss: 0.6282 - roc_auc: 0.6688 - val_accuracy: 0.6253 - val_loss: 0.7484 - val_roc_auc: 0.4936 - learning_rate: 5.0000e-04
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6631 - loss: 0.6300 - roc_auc: 0.6688 - val_accuracy: 0.6298 - val_loss: 0.7532 - val_roc_auc: 0.4875 - learning_rate: 5.0000e-04
# Epoch 14/100
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6473 - loss: 0.6319 - roc_auc: 0.6527
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6453 - loss: 0.6326 - roc_auc: 0.6568 - val_accuracy: 0.6117 - val_loss: 0.7532 - val_roc_auc: 0.4854 - learning_rate: 5.0000e-04
# Entrenando modelo LSTM 5d BASE sentimiento con 64 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6125 - loss: 0.6780 - roc_auc: 0.5186 - val_accuracy: 0.6524 - val_loss: 0.6636 - val_roc_auc: 0.4998 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6153 - loss: 0.6665 - roc_auc: 0.5671 - val_accuracy: 0.6524 - val_loss: 0.6682 - val_roc_auc: 0.5006 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6164 - loss: 0.6640 - roc_auc: 0.5770 - val_accuracy: 0.6524 - val_loss: 0.6693 - val_roc_auc: 0.5111 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6175 - loss: 0.6552 - roc_auc: 0.6040 - val_accuracy: 0.6433 - val_loss: 0.6798 - val_roc_auc: 0.5053 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6141 - loss: 0.6548 - roc_auc: 0.6089 - val_accuracy: 0.6343 - val_loss: 0.7020 - val_roc_auc: 0.4906 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6353 - loss: 0.6444 - roc_auc: 0.6369 - val_accuracy: 0.6072 - val_loss: 0.7153 - val_roc_auc: 0.4827 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6236 - loss: 0.6402 - roc_auc: 0.6513 - val_accuracy: 0.5982 - val_loss: 0.7362 - val_roc_auc: 0.4899 - learning_rate: 0.0010
# Epoch 8/100
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6568 - loss: 0.6233 - roc_auc: 0.6844
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6353 - loss: 0.6360 - roc_auc: 0.6572 - val_accuracy: 0.5801 - val_loss: 0.7499 - val_roc_auc: 0.4780 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6604 - loss: 0.6242 - roc_auc: 0.6850 - val_accuracy: 0.5666 - val_loss: 0.7629 - val_roc_auc: 0.4765 - learning_rate: 5.0000e-04
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6520 - loss: 0.6187 - roc_auc: 0.6916 - val_accuracy: 0.5734 - val_loss: 0.7638 - val_roc_auc: 0.4877 - learning_rate: 5.0000e-04
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6659 - loss: 0.6191 - roc_auc: 0.6907 - val_accuracy: 0.5643 - val_loss: 0.7896 - val_roc_auc: 0.4696 - learning_rate: 5.0000e-04
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6526 - loss: 0.6161 - roc_auc: 0.6980 - val_accuracy: 0.5508 - val_loss: 0.7855 - val_roc_auc: 0.4792 - learning_rate: 5.0000e-04
# Epoch 13/100
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6949 - loss: 0.6093 - roc_auc: 0.7052
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6787 - loss: 0.6119 - roc_auc: 0.7019 - val_accuracy: 0.5463 - val_loss: 0.8161 - val_roc_auc: 0.4617 - learning_rate: 5.0000e-04

# %% [markdown]
# **Guardado de resultados**
# - Exportación a CSV para combinar en Notebook de resultados `NB05a_Resultados.ipynb`

# %%
os.makedirs(OUT_DIR, exist_ok=True)

df_res = pd.DataFrame(resultados_totales)
df_res["Conf_Matrix"] = df_res["Conf_Matrix"].astype(str)
df_res.to_csv(OUT_PATH, index=False)
if os.path.exists(OUT_PATH): 
    print(f"Archivo guardado correctamente en {OUT_PATH}") 
else: 
    print("Error: el archivo no se ha guardado.")
df_res
# Out:
# Archivo guardado correctamente en ../../resultados/resultados_lstm_5d.csv
#   Familia   Modelo Horizonte Sentimiento       Acc  B_Acc  Precision  Recall  \
# 0      DL  LSTM_32        5d        BASE  0.564486    0.5   0.564486     1.0
# 1      DL  LSTM_64        5d        BASE  0.564486    0.5   0.564486     1.0
#
#          F1   ROC_AUC              Conf_Matrix
# 0  0.721625  0.508825  [[  0 233]\n [  0 302]]
# 1  0.721625  0.504434  [[  0 233]\n [  0 302]]
