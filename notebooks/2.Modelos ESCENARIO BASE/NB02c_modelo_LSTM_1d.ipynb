# %% [markdown]
# ### Notebook *NB02c – Modelo LSTM sin sentimiento (horizonte 1 día)*
# **Autor:** Jesús Daniel Romeral Cortina
#
# **Objetivo:**
# Entrenar y evaluar un modelo basado en redes neuronales recurrentes (LSTM) utilizando exclusivamente variables financieras del S&P 500, sin incorporar información de sentimiento, con el fin de establecer un baseline de referencia para la predicción direccional a 1 día.
#
# **Metodología (resumen):**
# - Se emplean únicamente variables financieras a partir del dataset `sp500_model.csv`.
# - **Split temporal**: train anterior a **2022-01-01** y test posterior.
# - Preparación de datos para LSTM mediante creación de secuencias con **lookback** fijo.
# - Validación temporal interna: el último 20% del conjunto de entrenamiento se usa como validación.
# - Ajuste de hiperparámetros limitado: se comparan dos tamaños de red (nº de neuronas, p. ej. 32 y 64), manteniendo el resto de parámetros fijos.
# - Métrica principal: **ROC_AUC** (además de Acc, B_Acc, Precision, Recall y F1).
# - Métricas guardadas en `resultados_lstm_1d.csv`.

# %%
import numpy as np
import pandas as pd
import os
import random
from sklearn.preprocessing import SstandardScaler
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score, confusion_matrix, roc_auc_score, precision_score, recall_score)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
# Out:
# 2026-03-02 22:16:41.006606: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
FAMILIA = "DL"
MODELO_BASE = "LSTM" 
HORIZONTE = "1d" 
SENTIMIENTO = "BASE"

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
MODEL_PATH   = "../../datos/sp500_model.csv"
OUT_DIR = "../../resultados"
OUT_PATH = "../../resultados/resultados_lstm_1d.csv"

# %%
df = pd.read_csv(MODEL_PATH, parse_dates=["Date"])
df = df.sort_values("Date").set_index("Date")
df.head()
# Out:
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
# 2013-01-07  1461.890015  1466.469971  1456.619995  1466.469971  3304970000
# 2013-01-08  1457.150024  1461.890015  1451.640015  1461.890015  3601600000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  \
# Date
# 2013-01-02  0.025403          0          -0.000957          0   0.016942
# 2013-01-03 -0.002086          1           0.008737          1   0.025403
# 2013-01-04  0.004865          0           0.003805          1  -0.002086
# 2013-01-07 -0.003123          0           0.006013          1   0.004865
# 2013-01-08 -0.003242          1           0.010424          1  -0.003123
#
#             ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  ret_ma_5  ret_std_5  \
# Date
# 2013-01-02  -0.011050  -0.001218  -0.004787  -0.002440  0.005058   0.015419
# 2013-01-03   0.016942  -0.011050  -0.001218  -0.004787  0.005598   0.015030
# 2013-01-04   0.025403   0.016942  -0.011050  -0.001218  0.006815   0.014580
# 2013-01-07  -0.002086   0.025403   0.016942  -0.011050  0.008400   0.012423
# 2013-01-08   0.004865  -0.002086   0.025403   0.016942  0.004363   0.012231
#
#             ret_ma_10  ret_std_10
# Date
# 2013-01-02   0.002286    0.012203
# 2013-01-03   0.000928    0.011814
# 2013-01-04   0.002174    0.011468
# 2013-01-07   0.001313    0.011515
# 2013-01-08   0.001926    0.011035

# %%
print("Shape:", df.shape)
print("Rango fechas:", df.index.min(), "-", df.index.max())
df.head(3)
# Out:
# Shape: (2811, 18)
# Rango fechas: 2013-01-02 00:00:00 - 2024-03-04 00:00:00
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  \
# Date
# 2013-01-02  0.025403          0          -0.000957          0   0.016942
# 2013-01-03 -0.002086          1           0.008737          1   0.025403
# 2013-01-04  0.004865          0           0.003805          1  -0.002086
#
#             ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  ret_ma_5  ret_std_5  \
# Date
# 2013-01-02  -0.011050  -0.001218  -0.004787  -0.002440  0.005058   0.015419
# 2013-01-03   0.016942  -0.011050  -0.001218  -0.004787  0.005598   0.015030
# 2013-01-04   0.025403   0.016942  -0.011050  -0.001218  0.006815   0.014580
#
#             ret_ma_10  ret_std_10
# Date
# 2013-01-02   0.002286    0.012203
# 2013-01-03   0.000928    0.011814
# 2013-01-04   0.002174    0.011468

# %% [markdown]
# **Target (1 día)**
# - *Target_1d* es la etiqueta binaria a predecir.
# - Se elimina features *forward* para evitar fuga de información.

# %%
Y = df["Target_1d"]
X = df.drop(columns=[
    "Target_1d", 
    "Target_5d", 
    "Return_5d_forward",
    "Close",
    "High",
    "Low",
    "Open",
    "Volume"
]) 
X.head(3)
# Out:
#               Return  ret_lag_1  ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  \
# Date
# 2013-01-02  0.025403   0.016942  -0.011050  -0.001218  -0.004787  -0.002440
# 2013-01-03 -0.002086   0.025403   0.016942  -0.011050  -0.001218  -0.004787
# 2013-01-04  0.004865  -0.002086   0.025403   0.016942  -0.011050  -0.001218
#
#             ret_ma_5  ret_std_5  ret_ma_10  ret_std_10
# Date
# 2013-01-02  0.005058   0.015419   0.002286    0.012203
# 2013-01-03  0.005598   0.015030   0.000928    0.011814
# 2013-01-04  0.006815   0.014580   0.002174    0.011468

# %% [markdown]
# **Split temporal por fecha (train/test)**
# Con embargo por horizonte

# %%
H = 1
train_mask = df.index < "2022-01-01"

X_train_raw = X.loc[train_mask].iloc[:-H]
y_train     = Y.loc[train_mask].iloc[:-H]

X_test_raw  = X.loc[~train_mask]
y_test      = Y.loc[~train_mask]

assert X_train_raw.index.max() < X_test_raw.index.min()
assert (X_train_raw.index == y_train.index).all()


print("Train:", X_train_raw.shape, "Test:",X_test_raw.shape)

pos_train = y_train.sum()
pos_test = y_test.sum()
print("Porcentaje positivos en train:", round(pos_train/ len(y_train) * 100, 1),"%")
print("Porcentaje positivos en test:", round(pos_test / len(y_test) * 100, 1),"%")
# Out:
# Train: (2266, 10) Test: (544, 10)
# Porcentaje positivos en train: 55.3 %
# Porcentaje positivos en test: 49.4 %

# %% [markdown]
# **Split temporal por fechas (train/val)** EN RAW + gap=H (embargo entre train y val)

# %%
val_size_raw = int(len(X_train_raw) * 0.2)
val_start_raw = len(X_train_raw) - val_size_raw

train_end_raw = max(0, val_start_raw - H)

X_tr_raw = X_train_raw.iloc[:train_end_raw]
y_tr = y_train.iloc[:train_end_raw]

X_val_raw = X_train_raw.iloc[val_start_raw:]
y_val = y_train.iloc[val_start_raw:]

# %%
print("TRAIN:", X_tr_raw.index[0],"-",X_tr_raw.index[-1],"n=", len(X_tr_raw))
print("VAL  :", X_val_raw.index[0],"-",X_val_raw.index[-1],  "n=", len(X_val_raw))
print("TEST :", X_test_raw.index[0],"-",X_test_raw.index[-1],"n=", len(X_test_raw))
# Out:
# TRAIN: 2013-01-02 00:00:00 - 2020-03-13 00:00:00 n= 1812
# VAL  : 2020-03-17 00:00:00 - 2021-12-30 00:00:00 n= 453
# TEST : 2022-01-03 00:00:00 - 2024-03-04 00:00:00 n= 544

# %% [markdown]
# **Escalado** (Fit solo al train real)

# %%
scaler = StandardScaler()
X_tr_scaled = scaler.fit_transform(X_tr_raw)
X_val_scaled = scaler.transform(X_val_raw)
X_test_scaled = scaler.transform(X_test_raw)

# %% [markdown]
# **Preparación de secuencias (LSTM)**

# %%
def make_sequences(X: np.ndarray, y: np.ndarray, lookback: int):
    X_seq, y_seq = [], []
    for t in range(lookback - 1, len(X)):
        X_seq.append(X[t - lookback + 1:t + 1])
        y_seq.append(y[t])
    return np.asarray(X_seq, np.float32), np.asarray(y_seq, np.int32)

# %%
lookback = 10  
X_tr_seq, y_tr_seq = make_sequences(X_tr_scaled, y_tr.values, lookback)
X_val_seq, y_val_seq = make_sequences(X_val_scaled, y_val.values, lookback)
X_test_seq, y_test_seq = make_sequences(X_test_scaled, y_test.values, lookback)

# %%
print(f"Entrenamiento: {X_tr_seq.shape}")
print(f"Prueba (validación): {X_val_seq.shape}") 
print(f"Prueba (Test): {X_test_seq.shape}")

print("X_tr_seq:", X_tr_seq.shape, "y_train_seq:", y_tr_seq.shape)
print("X_val_seq :", X_val_seq.shape,  "y_val_seq :", y_val_seq.shape)
print("X_test_seq :", X_test_seq.shape,  "y_test_seq :", y_test_seq.shape)

test_dates_seq = X_test_raw.index[lookback-1:]
print("Fechas test (seq):", test_dates_seq.min(), "->", test_dates_seq.max())
# Out:
# Entrenamiento: (1803, 10, 10)
# Prueba (validación): (444, 10, 10)
# Prueba (Test): (535, 10, 10)
# X_tr_seq: (1803, 10, 10) y_train_seq: (1803,)
# X_val_seq : (444, 10, 10) y_val_seq : (444,)
# X_test_seq : (535, 10, 10) y_test_seq : (535,)
# Fechas test (seq): 2022-01-14 00:00:00 -> 2024-03-04 00:00:00

# %% [markdown]
# **Ajuste de hiperparámetros (grid reducido) y entreno**
# - Se compara un conjunto reducido de tamaños de red (nº de neuronas: 32 y 64) para controlar la complejidad del modelo.
# - Se mantiene el resto de parámetros fijos.

# %%
n_features = X_tr_seq.shape[-1]

resultados_totales = []
neuronas_list = [32, 64] 

for neuronas in neuronas_list:
    print (f"Entrenando modelo {MODELO_BASE} {HORIZONTE} {SENTIMIENTO} sentimiento con {neuronas} neuronas...")
    model = models.Sequential([
        layers.Input(shape=(lookback, n_features)),
        layers.LSTM(neuronas, return_sequences=False,kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(neuronas//2, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="roc_auc", curve="ROC")])
    
    callbacks = [
        EarlyStopping(monitor="val_roc_auc", mode="max",patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_roc_auc", mode="max", factor=0.5, patience=5, min_lr=1e-5, verbose=1,)
    ]
  
    
    history = model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    
    y_proba = model.predict(X_test_seq, verbose=0).ravel()
    y_pred  = (y_proba >= 0.5).astype(int)  
    

    metrics = {
        "Familia": FAMILIA,
        "Modelo": f"{MODELO_BASE}_{neuronas}",
        "Horizonte": HORIZONTE,
        "Sentimiento" : SENTIMIENTO,
        "Acc": accuracy_score(y_test_seq, y_pred),
        "B_Acc": balanced_accuracy_score(y_test_seq, y_pred),
        "Precision": precision_score(y_test_seq, y_pred, zero_division=0),
        "Recall": recall_score(y_test_seq, y_pred, zero_division=0),
        "F1": f1_score(y_test_seq, y_pred, zero_division=0),
        "ROC_AUC": roc_auc_score(y_test_seq, y_proba),
        "Conf_Matrix": confusion_matrix(y_test_seq, y_pred),
    }





    resultados_totales.append(metrics)
# Out:
# Entrenando modelo LSTM 1d BASE sentimiento con 32 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.5369 - loss: 0.6947 - roc_auc: 0.5143 - val_accuracy: 0.5518 - val_loss: 0.6926 - val_roc_auc: 0.4584 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5585 - loss: 0.6907 - roc_auc: 0.5373 - val_accuracy: 0.5608 - val_loss: 0.6924 - val_roc_auc: 0.4623 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5308 - loss: 0.6943 - roc_auc: 0.5079 - val_accuracy: 0.5766 - val_loss: 0.6906 - val_roc_auc: 0.4751 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5446 - loss: 0.6927 - roc_auc: 0.5224 - val_accuracy: 0.5743 - val_loss: 0.6897 - val_roc_auc: 0.4755 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5557 - loss: 0.6891 - roc_auc: 0.5453 - val_accuracy: 0.5833 - val_loss: 0.6890 - val_roc_auc: 0.4880 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5507 - loss: 0.6888 - roc_auc: 0.5484 - val_accuracy: 0.5766 - val_loss: 0.6897 - val_roc_auc: 0.4789 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5607 - loss: 0.6875 - roc_auc: 0.5588 - val_accuracy: 0.5901 - val_loss: 0.6907 - val_roc_auc: 0.4828 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5485 - loss: 0.6868 - roc_auc: 0.5583 - val_accuracy: 0.5878 - val_loss: 0.6904 - val_roc_auc: 0.4847 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5530 - loss: 0.6871 - roc_auc: 0.5529 - val_accuracy: 0.5833 - val_loss: 0.6905 - val_roc_auc: 0.4833 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5441 - loss: 0.6866 - roc_auc: 0.5546 - val_accuracy: 0.5743 - val_loss: 0.6908 - val_roc_auc: 0.4888 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5646 - loss: 0.6838 - roc_auc: 0.5723 - val_accuracy: 0.5743 - val_loss: 0.6896 - val_roc_auc: 0.4962 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5652 - loss: 0.6847 - roc_auc: 0.5704 - val_accuracy: 0.5721 - val_loss: 0.6882 - val_roc_auc: 0.5031 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5557 - loss: 0.6858 - roc_auc: 0.5610 - val_accuracy: 0.5766 - val_loss: 0.6888 - val_roc_auc: 0.5024 - learning_rate: 0.0010
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5657 - loss: 0.6848 - roc_auc: 0.5603 - val_accuracy: 0.5788 - val_loss: 0.6893 - val_roc_auc: 0.5013 - learning_rate: 0.0010
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5552 - loss: 0.6833 - roc_auc: 0.5741 - val_accuracy: 0.5676 - val_loss: 0.6892 - val_roc_auc: 0.5027 - learning_rate: 0.0010
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5685 - loss: 0.6807 - roc_auc: 0.5841 - val_accuracy: 0.5788 - val_loss: 0.6904 - val_roc_auc: 0.4960 - learning_rate: 0.0010
# Epoch 17/100
# 47/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5818 - loss: 0.6800 - roc_auc: 0.5970
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5785 - loss: 0.6806 - roc_auc: 0.5928 - val_accuracy: 0.5811 - val_loss: 0.6905 - val_roc_auc: 0.5027 - learning_rate: 0.0010
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5796 - loss: 0.6819 - roc_auc: 0.5861 - val_accuracy: 0.5856 - val_loss: 0.6908 - val_roc_auc: 0.5066 - learning_rate: 5.0000e-04
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5935 - loss: 0.6786 - roc_auc: 0.6015 - val_accuracy: 0.5878 - val_loss: 0.6916 - val_roc_auc: 0.4995 - learning_rate: 5.0000e-04
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5851 - loss: 0.6756 - roc_auc: 0.6065 - val_accuracy: 0.5856 - val_loss: 0.6903 - val_roc_auc: 0.5088 - learning_rate: 5.0000e-04
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5691 - loss: 0.6795 - roc_auc: 0.5927 - val_accuracy: 0.5901 - val_loss: 0.6905 - val_roc_auc: 0.5106 - learning_rate: 5.0000e-04
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5785 - loss: 0.6791 - roc_auc: 0.5911 - val_accuracy: 0.5946 - val_loss: 0.6915 - val_roc_auc: 0.5066 - learning_rate: 5.0000e-04
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5868 - loss: 0.6767 - roc_auc: 0.6090 - val_accuracy: 0.5878 - val_loss: 0.6925 - val_roc_auc: 0.5044 - learning_rate: 5.0000e-04
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5846 - loss: 0.6782 - roc_auc: 0.5955 - val_accuracy: 0.5811 - val_loss: 0.6925 - val_roc_auc: 0.5060 - learning_rate: 5.0000e-04
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5907 - loss: 0.6751 - roc_auc: 0.6128 - val_accuracy: 0.5811 - val_loss: 0.6921 - val_roc_auc: 0.5091 - learning_rate: 5.0000e-04
# Epoch 26/100
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5743 - loss: 0.6769 - roc_auc: 0.5913
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5813 - loss: 0.6788 - roc_auc: 0.5940 - val_accuracy: 0.5856 - val_loss: 0.6922 - val_roc_auc: 0.5068 - learning_rate: 5.0000e-04
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5923 - loss: 0.6732 - roc_auc: 0.6190 - val_accuracy: 0.5766 - val_loss: 0.6924 - val_roc_auc: 0.5101 - learning_rate: 2.5000e-04
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5879 - loss: 0.6760 - roc_auc: 0.6054 - val_accuracy: 0.5743 - val_loss: 0.6940 - val_roc_auc: 0.5083 - learning_rate: 2.5000e-04
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5918 - loss: 0.6719 - roc_auc: 0.6178 - val_accuracy: 0.5788 - val_loss: 0.6944 - val_roc_auc: 0.5083 - learning_rate: 2.5000e-04
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5923 - loss: 0.6725 - roc_auc: 0.6173 - val_accuracy: 0.5698 - val_loss: 0.6963 - val_roc_auc: 0.5015 - learning_rate: 2.5000e-04
# Epoch 31/100
# 48/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5946 - loss: 0.6691 - roc_auc: 0.6185
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5896 - loss: 0.6732 - roc_auc: 0.6137 - val_accuracy: 0.5653 - val_loss: 0.6953 - val_roc_auc: 0.5047 - learning_rate: 2.5000e-04
# Entrenando modelo LSTM 1d BASE sentimiento con 64 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5380 - loss: 0.6974 - roc_auc: 0.5081 - val_accuracy: 0.5788 - val_loss: 0.6923 - val_roc_auc: 0.4628 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5446 - loss: 0.6968 - roc_auc: 0.4988 - val_accuracy: 0.5811 - val_loss: 0.6911 - val_roc_auc: 0.4817 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5480 - loss: 0.6921 - roc_auc: 0.5395 - val_accuracy: 0.5766 - val_loss: 0.6905 - val_roc_auc: 0.4839 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5485 - loss: 0.6896 - roc_auc: 0.5486 - val_accuracy: 0.5721 - val_loss: 0.6921 - val_roc_auc: 0.4772 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5491 - loss: 0.6908 - roc_auc: 0.5421 - val_accuracy: 0.5586 - val_loss: 0.6930 - val_roc_auc: 0.4766 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5530 - loss: 0.6900 - roc_auc: 0.5520 - val_accuracy: 0.5608 - val_loss: 0.6927 - val_roc_auc: 0.4808 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5585 - loss: 0.6887 - roc_auc: 0.5597 - val_accuracy: 0.5586 - val_loss: 0.6918 - val_roc_auc: 0.4880 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5535 - loss: 0.6888 - roc_auc: 0.5602 - val_accuracy: 0.5586 - val_loss: 0.6908 - val_roc_auc: 0.4918 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5496 - loss: 0.6857 - roc_auc: 0.5705 - val_accuracy: 0.5676 - val_loss: 0.6908 - val_roc_auc: 0.5004 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5785 - loss: 0.6852 - roc_auc: 0.5723 - val_accuracy: 0.5811 - val_loss: 0.6922 - val_roc_auc: 0.4970 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5646 - loss: 0.6859 - roc_auc: 0.5669 - val_accuracy: 0.5856 - val_loss: 0.6932 - val_roc_auc: 0.4962 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5746 - loss: 0.6820 - roc_auc: 0.5835 - val_accuracy: 0.5743 - val_loss: 0.6938 - val_roc_auc: 0.5023 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5779 - loss: 0.6819 - roc_auc: 0.5879 - val_accuracy: 0.5541 - val_loss: 0.6961 - val_roc_auc: 0.4982 - learning_rate: 0.0010
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5768 - loss: 0.6808 - roc_auc: 0.5886 - val_accuracy: 0.5473 - val_loss: 0.6974 - val_roc_auc: 0.5081 - learning_rate: 0.0010
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5779 - loss: 0.6759 - roc_auc: 0.6046 - val_accuracy: 0.5450 - val_loss: 0.7010 - val_roc_auc: 0.4999 - learning_rate: 0.0010
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5846 - loss: 0.6717 - roc_auc: 0.6130 - val_accuracy: 0.5450 - val_loss: 0.7035 - val_roc_auc: 0.4996 - learning_rate: 0.0010
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5896 - loss: 0.6711 - roc_auc: 0.6090 - val_accuracy: 0.5338 - val_loss: 0.7083 - val_roc_auc: 0.5009 - learning_rate: 0.0010
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6045 - loss: 0.6715 - roc_auc: 0.6201 - val_accuracy: 0.5338 - val_loss: 0.7098 - val_roc_auc: 0.4975 - learning_rate: 0.0010
# Epoch 19/100
# 52/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6033 - loss: 0.6658 - roc_auc: 0.6313
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5907 - loss: 0.6678 - roc_auc: 0.6195 - val_accuracy: 0.5315 - val_loss: 0.7135 - val_roc_auc: 0.5036 - learning_rate: 0.0010
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5946 - loss: 0.6624 - roc_auc: 0.6288 - val_accuracy: 0.5203 - val_loss: 0.7166 - val_roc_auc: 0.5071 - learning_rate: 5.0000e-04
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6134 - loss: 0.6588 - roc_auc: 0.6428 - val_accuracy: 0.5225 - val_loss: 0.7241 - val_roc_auc: 0.5054 - learning_rate: 5.0000e-04
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6140 - loss: 0.6552 - roc_auc: 0.6410 - val_accuracy: 0.5135 - val_loss: 0.7295 - val_roc_auc: 0.5033 - learning_rate: 5.0000e-04
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6073 - loss: 0.6549 - roc_auc: 0.6410 - val_accuracy: 0.5180 - val_loss: 0.7321 - val_roc_auc: 0.5024 - learning_rate: 5.0000e-04
# Epoch 24/100
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6275 - loss: 0.6525 - roc_auc: 0.6552
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6134 - loss: 0.6556 - roc_auc: 0.6449 - val_accuracy: 0.5248 - val_loss: 0.7280 - val_roc_auc: 0.5058 - learning_rate: 5.0000e-04

# %% [markdown]
# **Guardado de resultados**
# - Exportación a CSV para combinar en Notebook de resultados `NB05a_Resultados.ipynb`

# %%
os.makedirs(OUT_DIR, exist_ok=True)

df_res = pd.DataFrame(resultados_totales)
df_res["Conf_Matrix"] = df_res["Conf_Matrix"].astype(str)
df_res.to_csv(OUT_PATH, index=False)
if os.path.exists(OUT_PATH): 
    print(f"Archivo guardado correctamente en {OUT_PATH}") 
else: 
    print("Error: el archivo no se ha guardado.")
df_res
# Out:
# Archivo guardado correctamente en ../../resultados/resultados_lstm_1d.csv
#   Familia   Modelo Horizonte Sentimiento       Acc     B_Acc  Precision  \
# 0      DL  LSTM_32        1d        BASE  0.478505  0.480532   0.485900
# 1      DL  LSTM_64        1d        BASE  0.493458  0.495423   0.494505
#
#      Recall        F1   ROC_AUC              Conf_Matrix
# 0  0.842105  0.616231  0.464782  [[ 32 237]\n [ 42 224]]
# 1  0.845865  0.624133  0.487757  [[ 39 230]\n [ 41 225]]
