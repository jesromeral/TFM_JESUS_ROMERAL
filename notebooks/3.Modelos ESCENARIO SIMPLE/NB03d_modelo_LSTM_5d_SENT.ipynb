# %% [markdown]
# ### Notebook *NB03d – Modelo LSTM con sentimiento (horizonte 5 días)*
# **Autor:** Jesús Daniel Romeral Cortina
#
# **Objetivo:**
# Entrenar y evaluar el modelo LSTM utilizando variables financieras del S&P 500 junto con variables de sentimiento extraídas de noticias financieras, con el fin de analizar si la incorporación de sentimiento mejora la capacidad predictiva en la predicción direccional a 5 días frente al baseline sin sentimiento.
#
# **Metodología (resumen):**
# - Se emplean variables financieras y de sentimiento a partir del dataset `sp500_sent_model.csv`.
# - **Split temporal**: train anterior a **2022-01-01** y test posterior.
# - Preparación de datos para LSTM mediante creación de secuencias con **lookback** fijo.
# - Validación temporal interna: el último 20% del conjunto de entrenamiento se usa como validación.
# - Las neuronas selecionadas son a partir de la mejor metrica sacada del modelo lstm 5d sin sentimiento para una compaación justa, manteniendo el resto de parámetros iguales.
# - Métrica principal: **ROC_AUC** (además de Acc, B_Acc, Precision, Recall y F1).
# - Métricas guardadas en `resultados_lstm_5d_SENT.csv`.

# %%
import numpy as np
import pandas as pd
import os
import random
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (accuracy_score, balanced_accuracy_score, f1_score, confusion_matrix, roc_auc_score, precision_score, recall_score)
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
# Out:
# 2026-02-20 11:08:29.400776: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
FAMILIA = "DL"
MODELO_BASE = "LSTM" 
HORIZONTE = "5d" 
SENTIMIENTO = "SIMPLE"

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
MODEL_PATH   = "../../datos/sp500_sent_model.csv"
OUT_DIR = "../../resultados"
OUT_PATH = "../../resultados/resultados_lstm_5d_SENT.csv"

# %%
df = pd.read_csv(MODEL_PATH, parse_dates=["Date"])
df = df.sort_values("Date").set_index("Date")
df.head()
# Out:
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
# 2013-01-07  1461.890015  1466.469971  1456.619995  1466.469971  3304970000
# 2013-01-08  1457.150024  1461.890015  1451.640015  1461.890015  3601600000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  ...  \
# Date                                                                      ...
# 2013-01-02  0.025403          0          -0.000957          0   0.016942  ...
# 2013-01-03 -0.002086          1           0.008737          1   0.025403  ...
# 2013-01-04  0.004865          0           0.003805          1  -0.002086  ...
# 2013-01-07 -0.003123          0           0.006013          1   0.004865  ...
# 2013-01-08 -0.003242          1           0.010424          1  -0.003123  ...
#
#             ret_lag_5  ret_ma_5  ret_std_5  ret_ma_10  ret_std_10  \
# Date
# 2013-01-02  -0.002440  0.005058   0.015419   0.002286    0.012203
# 2013-01-03  -0.004787  0.005598   0.015030   0.000928    0.011814
# 2013-01-04  -0.001218  0.006815   0.014580   0.002174    0.011468
# 2013-01-07  -0.011050  0.008400   0.012423   0.001313    0.011515
# 2013-01-08   0.016942  0.004363   0.012231   0.001926    0.011035
#
#             sentiment_mean  n_news  n_news_filled  has_news  sentiment_filled
# Date
# 2013-01-02        0.470913     4.0            4.0         1          0.470913
# 2013-01-03        0.000000     2.0            2.0         1          0.000000
# 2013-01-04        0.000000     1.0            1.0         1          0.000000
# 2013-01-07        0.000000     2.0            2.0         1          0.000000
# 2013-01-08        0.244576     3.0            3.0         1          0.244576
#
# [5 rows x 23 columns]

# %%
print("Shape:", df.shape)
print("Rango fechas:", df.index.min(), "-", df.index.max())
df.head(3)
# Out:
# Shape: (2811, 23)
# Rango fechas: 2013-01-02 00:00:00 - 2024-03-04 00:00:00
#                   Close         High          Low         Open      Volume  \
# Date
# 2013-01-02  1462.420044  1462.430054  1426.189941  1426.189941  4202600000
# 2013-01-03  1459.369995  1465.469971  1455.530029  1462.420044  3829730000
# 2013-01-04  1466.469971  1467.939941  1458.989990  1459.369995  3424290000
#
#               Return  Target_1d  Return_5d_forward  Target_5d  ret_lag_1  ...  \
# Date                                                                      ...
# 2013-01-02  0.025403          0          -0.000957          0   0.016942  ...
# 2013-01-03 -0.002086          1           0.008737          1   0.025403  ...
# 2013-01-04  0.004865          0           0.003805          1  -0.002086  ...
#
#             ret_lag_5  ret_ma_5  ret_std_5  ret_ma_10  ret_std_10  \
# Date
# 2013-01-02  -0.002440  0.005058   0.015419   0.002286    0.012203
# 2013-01-03  -0.004787  0.005598   0.015030   0.000928    0.011814
# 2013-01-04  -0.001218  0.006815   0.014580   0.002174    0.011468
#
#             sentiment_mean  n_news  n_news_filled  has_news  sentiment_filled
# Date
# 2013-01-02        0.470913     4.0            4.0         1          0.470913
# 2013-01-03        0.000000     2.0            2.0         1          0.000000
# 2013-01-04        0.000000     1.0            1.0         1          0.000000
#
# [3 rows x 23 columns]

# %% [markdown]
# **Target (5 días)**
# - *Target_5d* es la etiqueta binaria a predecir.
# - Se elimina features *forward* para evitar fuga de información.

# %%
Y = df["Target_5d"]
X = df.drop(columns=[
    "Target_1d", 
    "Target_5d", 
    "Return_5d_forward",
    "Close",
    "High",
    "Low",
    "Open",
    "Volume",
    "sentiment_mean", 
    "n_news"
]) 
X.head(3)
# Out:
#               Return  ret_lag_1  ret_lag_2  ret_lag_3  ret_lag_4  ret_lag_5  \
# Date
# 2013-01-02  0.025403   0.016942  -0.011050  -0.001218  -0.004787  -0.002440
# 2013-01-03 -0.002086   0.025403   0.016942  -0.011050  -0.001218  -0.004787
# 2013-01-04  0.004865  -0.002086   0.025403   0.016942  -0.011050  -0.001218
#
#             ret_ma_5  ret_std_5  ret_ma_10  ret_std_10  n_news_filled  \
# Date
# 2013-01-02  0.005058   0.015419   0.002286    0.012203            4.0
# 2013-01-03  0.005598   0.015030   0.000928    0.011814            2.0
# 2013-01-04  0.006815   0.014580   0.002174    0.011468            1.0
#
#             has_news  sentiment_filled
# Date
# 2013-01-02         1          0.470913
# 2013-01-03         1          0.000000
# 2013-01-04         1          0.000000

# %% [markdown]
# **Split temporal por fecha (train/test)**
# Con embargo por horizonte

# %%
H = 5
train_mask = df.index < "2022-01-01"

X_train_raw = X.loc[train_mask].iloc[:-H]
y_train     = Y.loc[train_mask].iloc[:-H]

X_test_raw  = X.loc[~train_mask]
y_test      = Y.loc[~train_mask]

assert X_train_raw.index.max() < X_test_raw.index.min()
assert (X_train_raw.index == y_train.index).all()


print("Train:", X_train_raw.shape, "Test:",X_test_raw.shape)

pos_train = y_train.sum()
pos_test = y_test.sum()
print("Porcentaje positivos en train:", round(pos_train/ len(y_train) * 100, 1),"%")
print("Porcentaje positivos en test:", round(pos_test / len(y_test) * 100, 1),"%")
# Out:
# Train: (2262, 13) Test: (544, 13)
# Porcentaje positivos en train: 62.2 %
# Porcentaje positivos en test: 55.7 %

# %% [markdown]
# **Split temporal por fechas (train/val)** EN RAW + gap=H (embargo entre train y val)

# %%
val_size_raw = int(len(X_train_raw) * 0.2)
val_start_raw = len(X_train_raw) - val_size_raw

train_end_raw = max(0, val_start_raw - H)

X_tr_raw = X_train_raw.iloc[:train_end_raw]
y_tr = y_train.iloc[:train_end_raw]

X_val_raw = X_train_raw.iloc[val_start_raw:]
y_val = y_train.iloc[val_start_raw:]

# %%
print("TRAIN:", X_tr_raw.index[0],"-",X_tr_raw.index[-1],"n=", len(X_tr_raw))
print("VAL  :", X_val_raw.index[0],"-",X_val_raw.index[-1],  "n=", len(X_val_raw))
print("TEST :", X_test_raw.index[0],"-",X_test_raw.index[-1],"n=", len(X_test_raw))
# Out:
# TRAIN: 2013-01-02 00:00:00 - 2020-03-04 00:00:00 n= 1805
# VAL  : 2020-03-12 00:00:00 - 2021-12-23 00:00:00 n= 452
# TEST : 2022-01-03 00:00:00 - 2024-03-04 00:00:00 n= 544

# %% [markdown]
# **Escalado** (Fit solo al train real)

# %%
scaler = StandardScaler()
X_tr_scaled = scaler.fit_transform(X_tr_raw)
X_val_scaled = scaler.transform(X_val_raw)
X_test_scaled = scaler.transform(X_test_raw)

# %% [markdown]
# **Preparación de secuencias (LSTM)**

# %%
def make_sequences(X: np.ndarray, y: np.ndarray, lookback: int):
    X_seq, y_seq = [], []
    for t in range(lookback - 1, len(X)):
        X_seq.append(X[t - lookback + 1:t + 1])
        y_seq.append(y[t])
    return np.asarray(X_seq, np.float32), np.asarray(y_seq, np.int32)

# %%
lookback = 10  
X_tr_seq, y_tr_seq = make_sequences(X_tr_scaled, y_tr.values, lookback)
X_val_seq, y_val_seq = make_sequences(X_val_scaled, y_val.values, lookback)
X_test_seq, y_test_seq = make_sequences(X_test_scaled, y_test.values, lookback)

# %%
print(f"Entrenamiento: {X_tr_seq.shape}")
print(f"Prueba (validación): {X_val_seq.shape}") 
print(f"Prueba (Test): {X_test_seq.shape}")

print("X_tr_seq:", X_tr_seq.shape, "y_train_seq:", y_tr_seq.shape)
print("X_val_seq :", X_val_seq.shape,  "y_val_seq :", y_val_seq.shape)
print("X_test_seq :", X_test_seq.shape,  "y_test_seq :", y_test_seq.shape)

test_dates_seq = X_test_raw.index[lookback-1:]
print("Fechas test (seq):", test_dates_seq.min(), "->", test_dates_seq.max())
# Out:
# Entrenamiento: (1796, 10, 13)
# Prueba (validación): (443, 10, 13)
# Prueba (Test): (535, 10, 13)
# X_tr_seq: (1796, 10, 13) y_train_seq: (1796,)
# X_val_seq : (443, 10, 13) y_val_seq : (443,)
# X_test_seq : (535, 10, 13) y_test_seq : (535,)
# Fechas test (seq): 2022-01-14 00:00:00 -> 2024-03-04 00:00:00

# %% [markdown]
# **Ajuste de hiperparámetros (grid reducido) y entreno**
# - Se compara un conjunto reducido de tamaños de red (nº de neuronas: 32 y 64) para controlar la complejidad del modelo.
# - Se mantiene el resto de parámetros fijos.

# %%
n_features = X_tr_seq.shape[-1]

resultados_totales = []
neuronas_list = [32, 64] 

for neuronas in neuronas_list:
    print (f"Entrenando modelo {MODELO_BASE} {HORIZONTE} {SENTIMIENTO} sentimiento con {neuronas} neuronas...")
    model = models.Sequential([
        layers.Input(shape=(lookback, n_features)),
        layers.LSTM(neuronas, return_sequences=False,kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(neuronas//2, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="roc_auc", curve="ROC")])
    
    callbacks = [
        EarlyStopping(monitor="val_roc_auc", mode="max",patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_roc_auc", mode="max", factor=0.5, patience=5, min_lr=1e-5, verbose=1,)
    ]
  
    
    history = model.fit(
        X_tr_seq, y_tr_seq,
        validation_data=(X_val_seq, y_val_seq),
        epochs=100,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    
    y_proba = model.predict(X_test_seq, verbose=0).ravel()
    y_pred  = (y_proba >= 0.5).astype(int)  
    

    metrics = {
        "Familia": FAMILIA,
        "Modelo": f"{MODELO_BASE}_{neuronas}",
        "Horizonte": HORIZONTE,
        "Sentimiento" : SENTIMIENTO,
        "Acc": accuracy_score(y_test_seq, y_pred),
        "B_Acc": balanced_accuracy_score(y_test_seq, y_pred),
        "Precision": precision_score(y_test_seq, y_pred, zero_division=0),
        "Recall": recall_score(y_test_seq, y_pred, zero_division=0),
        "F1": f1_score(y_test_seq, y_pred, zero_division=0),
        "ROC_AUC": roc_auc_score(y_test_seq, y_proba),
        "Conf_Matrix": confusion_matrix(y_test_seq, y_pred),
    }





    resultados_totales.append(metrics)
# Out:
# Entrenando modelo LSTM 5d SIMPLE sentimiento con 32 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5997 - loss: 0.6743 - roc_auc: 0.5333 - val_accuracy: 0.6479 - val_loss: 0.6696 - val_roc_auc: 0.4420 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6108 - loss: 0.6654 - roc_auc: 0.5594 - val_accuracy: 0.6524 - val_loss: 0.6637 - val_roc_auc: 0.4745 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6158 - loss: 0.6629 - roc_auc: 0.5739 - val_accuracy: 0.6524 - val_loss: 0.6655 - val_roc_auc: 0.4910 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6108 - loss: 0.6592 - roc_auc: 0.5871 - val_accuracy: 0.6524 - val_loss: 0.6627 - val_roc_auc: 0.4992 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6236 - loss: 0.6485 - roc_auc: 0.6308 - val_accuracy: 0.6524 - val_loss: 0.6681 - val_roc_auc: 0.5048 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6231 - loss: 0.6469 - roc_auc: 0.6320 - val_accuracy: 0.6524 - val_loss: 0.6756 - val_roc_auc: 0.5093 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6253 - loss: 0.6418 - roc_auc: 0.6470 - val_accuracy: 0.6524 - val_loss: 0.6845 - val_roc_auc: 0.5075 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6470 - loss: 0.6342 - roc_auc: 0.6652 - val_accuracy: 0.6411 - val_loss: 0.6934 - val_roc_auc: 0.5067 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6464 - loss: 0.6268 - roc_auc: 0.6784 - val_accuracy: 0.6388 - val_loss: 0.7146 - val_roc_auc: 0.5106 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6420 - loss: 0.6250 - roc_auc: 0.6790 - val_accuracy: 0.6275 - val_loss: 0.7231 - val_roc_auc: 0.5094 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6693 - loss: 0.6121 - roc_auc: 0.7004 - val_accuracy: 0.6208 - val_loss: 0.7582 - val_roc_auc: 0.5064 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6704 - loss: 0.6013 - roc_auc: 0.7143 - val_accuracy: 0.6140 - val_loss: 0.7884 - val_roc_auc: 0.5059 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6910 - loss: 0.5902 - roc_auc: 0.7335 - val_accuracy: 0.6185 - val_loss: 0.8195 - val_roc_auc: 0.5102 - learning_rate: 0.0010
# Epoch 14/100
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6798 - loss: 0.5873 - roc_auc: 0.7286
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6860 - loss: 0.5868 - roc_auc: 0.7341 - val_accuracy: 0.6005 - val_loss: 0.8568 - val_roc_auc: 0.5067 - learning_rate: 0.0010
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6988 - loss: 0.5657 - roc_auc: 0.7664 - val_accuracy: 0.6140 - val_loss: 0.9169 - val_roc_auc: 0.5139 - learning_rate: 5.0000e-04
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7116 - loss: 0.5567 - roc_auc: 0.7747 - val_accuracy: 0.6050 - val_loss: 0.9572 - val_roc_auc: 0.5087 - learning_rate: 5.0000e-04
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7194 - loss: 0.5500 - roc_auc: 0.7838 - val_accuracy: 0.5937 - val_loss: 0.9766 - val_roc_auc: 0.5109 - learning_rate: 5.0000e-04
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7244 - loss: 0.5416 - roc_auc: 0.7893 - val_accuracy: 0.5914 - val_loss: 0.9946 - val_roc_auc: 0.5099 - learning_rate: 5.0000e-04
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7300 - loss: 0.5369 - roc_auc: 0.7944 - val_accuracy: 0.5824 - val_loss: 1.0304 - val_roc_auc: 0.5126 - learning_rate: 5.0000e-04
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7300 - loss: 0.5367 - roc_auc: 0.7952 - val_accuracy: 0.5937 - val_loss: 1.0548 - val_roc_auc: 0.5151 - learning_rate: 5.0000e-04
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7389 - loss: 0.5257 - roc_auc: 0.8056 - val_accuracy: 0.6005 - val_loss: 1.0597 - val_roc_auc: 0.5107 - learning_rate: 5.0000e-04
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7305 - loss: 0.5244 - roc_auc: 0.8047 - val_accuracy: 0.5869 - val_loss: 1.1025 - val_roc_auc: 0.5094 - learning_rate: 5.0000e-04
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7533 - loss: 0.5081 - roc_auc: 0.8220 - val_accuracy: 0.5824 - val_loss: 1.1270 - val_roc_auc: 0.5080 - learning_rate: 5.0000e-04
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7450 - loss: 0.4971 - roc_auc: 0.8295 - val_accuracy: 0.5869 - val_loss: 1.1680 - val_roc_auc: 0.5123 - learning_rate: 5.0000e-04
# Epoch 25/100
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7561 - loss: 0.4911 - roc_auc: 0.8307
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7478 - loss: 0.4970 - roc_auc: 0.8281 - val_accuracy: 0.5959 - val_loss: 1.1956 - val_roc_auc: 0.5138 - learning_rate: 5.0000e-04
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7745 - loss: 0.4967 - roc_auc: 0.8340 - val_accuracy: 0.5869 - val_loss: 1.2240 - val_roc_auc: 0.5125 - learning_rate: 2.5000e-04
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7656 - loss: 0.4897 - roc_auc: 0.8372 - val_accuracy: 0.5869 - val_loss: 1.2376 - val_roc_auc: 0.5135 - learning_rate: 2.5000e-04
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7550 - loss: 0.4936 - roc_auc: 0.8323 - val_accuracy: 0.5937 - val_loss: 1.2657 - val_roc_auc: 0.5104 - learning_rate: 2.5000e-04
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7695 - loss: 0.4835 - roc_auc: 0.8422 - val_accuracy: 0.5892 - val_loss: 1.2828 - val_roc_auc: 0.5078 - learning_rate: 2.5000e-04
# Epoch 30/100
# 51/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7783 - loss: 0.4819 - roc_auc: 0.8409
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7628 - loss: 0.4839 - roc_auc: 0.8411 - val_accuracy: 0.5937 - val_loss: 1.2862 - val_roc_auc: 0.5092 - learning_rate: 2.5000e-04
# Entrenando modelo LSTM 5d SIMPLE sentimiento con 64 neuronas...
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6097 - loss: 0.6780 - roc_auc: 0.5202 - val_accuracy: 0.6524 - val_loss: 0.6617 - val_roc_auc: 0.5083 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6147 - loss: 0.6637 - roc_auc: 0.5838 - val_accuracy: 0.6524 - val_loss: 0.6639 - val_roc_auc: 0.5085 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6158 - loss: 0.6595 - roc_auc: 0.5999 - val_accuracy: 0.6524 - val_loss: 0.6670 - val_roc_auc: 0.5189 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6236 - loss: 0.6467 - roc_auc: 0.6382 - val_accuracy: 0.6501 - val_loss: 0.6753 - val_roc_auc: 0.5217 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6197 - loss: 0.6482 - roc_auc: 0.6315 - val_accuracy: 0.6479 - val_loss: 0.6957 - val_roc_auc: 0.5137 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6487 - loss: 0.6296 - roc_auc: 0.6773 - val_accuracy: 0.6366 - val_loss: 0.7218 - val_roc_auc: 0.4934 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6442 - loss: 0.6217 - roc_auc: 0.6901 - val_accuracy: 0.6230 - val_loss: 0.7544 - val_roc_auc: 0.4967 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6748 - loss: 0.6016 - roc_auc: 0.7230 - val_accuracy: 0.5869 - val_loss: 0.7918 - val_roc_auc: 0.4887 - learning_rate: 0.0010
# Epoch 9/100
# 50/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6956 - loss: 0.5904 - roc_auc: 0.7299
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6832 - loss: 0.5885 - roc_auc: 0.7353 - val_accuracy: 0.5688 - val_loss: 0.8084 - val_roc_auc: 0.5041 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7099 - loss: 0.5666 - roc_auc: 0.7676 - val_accuracy: 0.5530 - val_loss: 0.8562 - val_roc_auc: 0.4987 - learning_rate: 5.0000e-04
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7094 - loss: 0.5586 - roc_auc: 0.7742 - val_accuracy: 0.5576 - val_loss: 0.8902 - val_roc_auc: 0.4961 - learning_rate: 5.0000e-04
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7110 - loss: 0.5489 - roc_auc: 0.7849 - val_accuracy: 0.5576 - val_loss: 0.9369 - val_roc_auc: 0.4939 - learning_rate: 5.0000e-04
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7249 - loss: 0.5418 - roc_auc: 0.7901 - val_accuracy: 0.5553 - val_loss: 0.9654 - val_roc_auc: 0.4890 - learning_rate: 5.0000e-04
# Epoch 14/100
# 49/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7368 - loss: 0.5296 - roc_auc: 0.7988
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7277 - loss: 0.5291 - roc_auc: 0.8013 - val_accuracy: 0.5553 - val_loss: 1.0093 - val_roc_auc: 0.4874 - learning_rate: 5.0000e-04

# %% [markdown]
# **Guardado de resultados**
# - Exportación a CSV para combinar en Notebook de resultados `NB05a_Resultados.ipynb`

# %%
os.makedirs(OUT_DIR, exist_ok=True)

df_res = pd.DataFrame(resultados_totales)
df_res["Conf_Matrix"] = df_res["Conf_Matrix"].astype(str)
df_res.to_csv(OUT_PATH, index=False)
if os.path.exists(OUT_PATH): 
    print(f"Archivo guardado correctamente en {OUT_PATH}") 
else: 
    print("Error: el archivo no se ha guardado.")
df_res
# Out:
# Archivo guardado correctamente en ../../resultados/resultados_lstm_5d_SENT.csv
#   Familia   Modelo Horizonte Sentimiento       Acc     B_Acc  Precision  \
# 0      DL  LSTM_32        5d      SIMPLE  0.551402  0.493804   0.561265
# 1      DL  LSTM_64        5d      SIMPLE  0.562617  0.498344   0.563670
#
#      Recall        F1   ROC_AUC              Conf_Matrix
# 0  0.940397  0.702970  0.541782  [[ 11 222]\n [ 18 284]]
# 1  0.996689  0.720096  0.547153  [[  0 233]\n [  1 301]]
